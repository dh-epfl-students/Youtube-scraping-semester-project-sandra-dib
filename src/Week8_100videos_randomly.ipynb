# %%
import pandas as pd
import random
import youtube_dl
import numpy
import cv2

# %%
inputfile = pd.read_csv('../data/video_info_2.csv',delimiter=',')

# %%
inputfile
# Out:
#               id                                    place  duration  \
# 0    SAm6Awzqyr8                         Aachen cathedral       417
# 1    vJ1HftOGa7o                         Aachen cathedral       215
# 2    7s5TYFPP6Uw                                 Abu mena       733
# 3    weK4NgWcUN8                     Dilmun burial mounds       805
# 4    -lzFLM8hte0                         Acropolis athens       136
# ..           ...                                      ...       ...
# 751  SijeZTOl7s4                        Xinjiang tianshan       229
# 752  35_7gL6W3kM                                   Yin xu       382
# 753  0Q3uf1YeTek                   Yosemite national park       169
# 754  IWi_kfryEEU                   Yosemite national park       120
# 755  nkRdPYuU0u0  Zollverein coal mine industrial complex        65
#
#                                                  title      date  height  \
# 0                      Aachen Highlights by drone 2021  20210505    2160
# 1       Lake Aachen (Achensee) - 4k drone based teaser  20180929    2160
# 2                      How to fly drones for beginners  20210624    2160
# 3    I went to Iceland to fly my drone over an acti...  20211008    2160
# 4       Acropolis by drone / Athens Aerial - ἀκρόπολις  20210622    2160
# ..                                                 ...       ...     ...
# 751  China's amazing INNER MONGOLIA grasslands by d...  20200910    2160
# 752  UK Drone Code (EXPLAINED) | 6 MUST KNOWS on ho...  20190611    2160
# 753  Yosemite National Park - California, USA 🇺🇸 - ...  20200508    2160
# 754  Tour de Teemu: Yosemite national park, USA. Oc...  20191020    2160
# 755            Mine. Mavic Pro sample drone footage 4K  20181214    2160
#
#        filesize
# 0     678002004
# 1     686665728
# 2     863190914
# 3    1052880396
# 4     252359734
# ..          ...
# 751   364998557
# 752   447087485
# 753   209016569
# 754   278322936
# 755   179716821
#
# [756 rows x 7 columns]

# %%
 unique_values = inputfile['place'].unique()

# %%
print(len(unique_values))
# Out:
# 428

# %%
df = pd.read_csv('../data/video_info_2.csv', delimiter=',')
dict_sample = {}
places_sel = random.sample(df.place.unique().tolist(), 100)
for place in places_sel:
    ids = df.loc[df['place'] == place].id.tolist()
    ids_sample = random.sample(ids, 1)
    dict_sample.update({place : ids_sample})

# %%
for key, value in dict_sample.items():
    
    place = key
    for youtube_id in value:
        print(youtube_id)
        video_url = 'https://www.youtube.com/watch?v=%s' % youtube_id  #The Youtube URL
        ydl_opts = {}
        ydl = youtube_dl.YoutubeDL(ydl_opts)
        info_dict = ydl.extract_info(video_url, download=False)

        formats = info_dict.get('formats',None)

        f = formats[-1]
        url = f.get('url',None)
        cap = cv2.VideoCapture(url)

        x = 1
        count = info_dict['duration'] / 4

        while x < 4 :

            for i in range(3):

                time = x * info_dict['duration'] + ( 10 * i ) # each time, take 3 shots at 10 sec intervals
                ret, frame = cap.read()
                if not ret:
                    break
                filename = "../data/screenshots/%s-%d.png" % (youtube_id, time)

                cv2.imwrite(filename, frame)
                count += int(info_dict['duration'] / 4)
                cap.set(1,count)

            x += 1

        cap.release()
# Out:
# n3OCG39W52Y
# [youtube] n3OCG39W52Y: Downloading webpage
# [youtube] n3OCG39W52Y: Downloading MPD manifest
# IUyOHjwAOTI
# [youtube] IUyOHjwAOTI: Downloading webpage
# [youtube] IUyOHjwAOTI: Downloading player 8eb5bf0c
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_252499/3157239576.py in <module>
#      30                 cv2.imwrite(filename, frame)
#      31                 count += int(info_dict['duration'] / 4)
# ---> 32                 cap.set(1,count)
#      33
#      34             x += 1
#
# KeyboardInterrupt:
